# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import psycopg2
import plotly.express as px


ipums = "//Users/timothycummins/Downloads/ipums_puma_2010"
ipum_df = gpd.read_file(ipums)
ipum_wa = ipum_df.loc[ipum_df['STATEFIP'] == '53']


DBNAME = "opportunity_youth"
conn = psycopg2.connect(dbname=DBNAME)
oypp = pd.read_sql("""SELECT DISTINCT(puma5ce) "PUMA", statefp, countyfp  FROM ct_puma_xwalk WHERE statefp = '53' and countyfp = '033' """, conn)

oypum = pd.merge(ipum_wa,oypp,how='right',on='PUMA')

oypum = oypum.dropna()
oypum.head()

puma_nums = ['11610', '11611', '11612', '11613', '11614', '11615']
oypum['skc'] = np.where(oypum['PUMA'].isin(puma_nums),'SOUTH KING COUNTY','THE REST OF\nKING COUNTY')

oypum['Name'] = oypum['Name'].map(lambda x: x.lstrip('King County  (Northwest)-- al)-- ').rstrip('PUMA (Northeast)'))
oypum['Name'][0] = 'Shoreline,\nKenmore,\nBothell'
oypum['Name'][1] = '\nBellevue'
oypum['Name'][2] = 'Renton,\nSkyway'
oypum['Name'][3] = 'Redmond,\nKirkland,\nInglewood'
oypum['Name'][4] = ''
oypum['Name'][5] = 'Capitol\nHill'
oypum['Name'][6] = 'Issaquah,\nMercer Island'
oypum['Name'][7] = 'Kent'
oypum['Name'][8] = 'Auburn'
oypum['Name'][9] = 'Maple Valley,\nCovington & Enumclaw'
oypum['Name'][10] = 'Seattle'
oypum['Name'][11] = 'Queen Anne'
oypum['Name'][12] = ''
oypum['Name'][13] = 'Burien,\nSeaTac,\nTukwila'
oypum['Name'][14] = 'Federal Way,\nDes Moines'
oypum['Name'][15] = 'Snoqualmie City,\nCottage Lake,\n Union Hill'

oypum.head(20)
# Out:
# <ipython-input-167-c93fbe47c17e>:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:32: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:33: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:34: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:35: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:37: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:38: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:39: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:40: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:41: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-167-c93fbe47c17e>:42: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     GISMATCH    GISJOIN    GEOID STATEFIP       State   PUMA  \
# 0    5311606  G53011606  5311606       53  Washington  11606
# 1    5311608  G53011608  5311608       53  Washington  11608
# 2    5311610  G53011610  5311610       53  Washington  11610
# 3    5311607  G53011607  5311607       53  Washington  11607
# 4    5311602  G53011602  5311602       53  Washington  11602
# 5    5311604  G53011604  5311604       53  Washington  11604
# 6    5311609  G53011609  5311609       53  Washington  11609
# 7    5311613  G53011613  5311613       53  Washington  11613
# 8    5311614  G53011614  5311614       53  Washington  11614
# 9    5311615  G53011615  5311615       53  Washington  11615
# 10   5311601  G53011601  5311601       53  Washington  11601
# 11   5311603  G53011603  5311603       53  Washington  11603
# 12   5311605  G53011605  5311605       53  Washington  11605
# 13   5311611  G53011611  5311611       53  Washington  11611
# 14   5311612  G53011612  5311612       53  Washington  11612
# 15   5311616  G53011616  5311616       53  Washington  11616
#
#                                             Name  \
# 0                  Shoreline,\nKenmore,\nBothell
# 1                                     \nBellevue
# 2                                Renton,\nSkyway
# 3                 Redmond,\nKirkland,\nInglewood
# 4
# 5                                  Capitol\nHill
# 6                       Issaquah,\nMercer Island
# 7                                           Kent
# 8                                         Auburn
# 9            Maple Valley,\nCovington & Enumclaw
# 10                                       Seattle
# 11                                    Queen Anne
# 12
# 13                     Burien,\nSeaTac,\nTukwila
# 14                      Federal Way,\nDes Moines
# 15  Snoqualmie City,\nCottage Lake,\n Union Hill
#
#                                              geometry statefp countyfp  \
# 0   MULTIPOLYGON (((-1957975.193 1416319.557, -195...      53      033
# 1   POLYGON ((-1957887.975 1404329.861, -1957903.8...      53      033
# 2   POLYGON ((-1955803.190 1386966.027, -1955824.1...      53      033
# 3   POLYGON ((-1952839.291 1412380.172, -1952643.4...      53      033
# 4   POLYGON ((-1960613.321 1414852.672, -1960610.3...      53      033
# 5   POLYGON ((-1963920.334 1390069.184, -1963980.0...      53      033
# 6   MULTIPOLYGON (((-1962059.734 1399443.982, -196...      53      033
# 7   POLYGON ((-1964607.872 1382415.161, -1964615.5...      53      033
# 8   POLYGON ((-1962306.184 1370551.322, -1962307.7...      53      033
# 9   POLYGON ((-1940930.854 1384594.946, -1940902.4...      53      033
# 10  POLYGON ((-1963511.255 1415726.391, -1963536.6...      53      033
# 11  POLYGON ((-1965323.380 1405827.419, -1965327.1...      53      033
# 12  POLYGON ((-1968576.117 1401689.853, -1968479.9...      53      033
# 13  POLYGON ((-1966384.054 1390783.957, -1966387.9...      53      033
# 14  MULTIPOLYGON (((-1973517.655 1381132.018, -197...      53      033
# 15  POLYGON ((-1949928.914 1416692.963, -1949919.9...      53      033
#
#                          skc
# 0   THE REST OF\nKING COUNTY
# 1   THE REST OF\nKING COUNTY
# 2          SOUTH KING COUNTY
# 3   THE REST OF\nKING COUNTY
# 4   THE REST OF\nKING COUNTY
# 5   THE REST OF\nKING COUNTY
# 6   THE REST OF\nKING COUNTY
# 7          SOUTH KING COUNTY
# 8          SOUTH KING COUNTY
# 9          SOUTH KING COUNTY
# 10  THE REST OF\nKING COUNTY
# 11  THE REST OF\nKING COUNTY
# 12  THE REST OF\nKING COUNTY
# 13         SOUTH KING COUNTY
# 14         SOUTH KING COUNTY
# 15  THE REST OF\nKING COUNTY

# %%
plt.rcParams['figure.figsize'] = [8, 6] #height, width

vmin, vmax = 0, 1

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(16,12))

# remove the axis
ax.axis('off')

# add a title and annotation
ax.set_title('\n SKC Vs KC', fontdict={'fontsize': '25', 'fontweight' : '3'})
# ax.legend(oypum['skc'],('SKC','KC'))

# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm.set_array([])

# cbar = fig.colorbar(sm)

# create map
oypum.plot(column=(oypum['skc']), cmap='Accent', linewidth=0.8, ax=ax, edgecolor='1', legend=True)

# Add Labels
oypum['coords'] = oypum['geometry'].apply(lambda x: x.representative_point().coords[:])
oypum['coords'] = [coords[0] for coords in oypum['coords']]

# Display names 
for idx, row in oypum.iterrows():
    plt.annotate(s=row['Name'], xy=row['coords'],horizontalalignment='center',size='9')
